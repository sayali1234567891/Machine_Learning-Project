# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/Ashish/Downloads/Loan_data_analysis_project/Loan_data_analysis_project/Loan_Dataset.csv')

# %%
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# 4       81536ad9-5ccf-4eb8-befb-47a4d608658e  Fully Paid             176220.0
# ...                                      ...         ...                  ...
# 100509                                   NaN         NaN                  NaN
# 100510                                   NaN         NaN                  NaN
# 100511                                   NaN         NaN                  NaN
# 100512                                   NaN         NaN                  NaN
# 100513                                   NaN         NaN                  NaN
#
#               Term  Credit Score  Annual Income Years in current job  \
# 0       Short Term         709.0      1167493.0              8 years
# 1       Short Term           NaN            NaN            10+ years
# 2       Short Term         741.0      2231892.0              8 years
# 3        Long Term         721.0       806949.0              3 years
# 4       Short Term           NaN            NaN              5 years
# ...            ...           ...            ...                  ...
# 100509         NaN           NaN            NaN                  NaN
# 100510         NaN           NaN            NaN                  NaN
# 100511         NaN           NaN            NaN                  NaN
# 100512         NaN           NaN            NaN                  NaN
# 100513         NaN           NaN            NaN                  NaN
#
#        Home Ownership             Purpose  Monthly Debt  \
# 0       Home Mortgage   Home Improvements       5214.74
# 1       Home Mortgage  Debt Consolidation      33295.98
# 2            Own Home  Debt Consolidation      29200.53
# 3            Own Home  Debt Consolidation       8741.90
# 4                Rent  Debt Consolidation      20639.70
# ...               ...                 ...           ...
# 100509            NaN                 NaN           NaN
# 100510            NaN                 NaN           NaN
# 100511            NaN                 NaN           NaN
# 100512            NaN                 NaN           NaN
# 100513            NaN                 NaN           NaN
#
#         Years of Credit History  Months since last delinquent  \
# 0                          17.2                           NaN
# 1                          21.1                           8.0
# 2                          14.9                          29.0
# 3                          12.0                           NaN
# 4                           6.1                           NaN
# ...                         ...                           ...
# 100509                      NaN                           NaN
# 100510                      NaN                           NaN
# 100511                      NaN                           NaN
# 100512                      NaN                           NaN
# 100513                      NaN                           NaN
#
#         Number of Open Accounts  Number of Credit Problems  \
# 0                           6.0                        1.0
# 1                          35.0                        0.0
# 2                          18.0                        1.0
# 3                           9.0                        0.0
# 4                          15.0                        0.0
# ...                         ...                        ...
# 100509                      NaN                        NaN
# 100510                      NaN                        NaN
# 100511                      NaN                        NaN
# 100512                      NaN                        NaN
# 100513                      NaN                        NaN
#
#         Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 0                     228190.0             416746.0           1.0        0.0
# 1                     229976.0             850784.0           0.0        0.0
# 2                     297996.0             750090.0           0.0        0.0
# 3                     256329.0             386958.0           0.0        0.0
# 4                     253460.0             427174.0           0.0        0.0
# ...                        ...                  ...           ...        ...
# 100509                     NaN                  NaN           NaN        NaN
# 100510                     NaN                  NaN           NaN        NaN
# 100511                     NaN                  NaN           NaN        NaN
# 100512                     NaN                  NaN           NaN        NaN
# 100513                     NaN                  NaN           NaN        NaN
#
# [100514 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
#  12  Months since last delinquent  46859 non-null   float64
#  13  Number of Open Accounts       100000 non-null  float64
#  14  Number of Credit Problems     100000 non-null  float64
#  15  Current Credit Balance        100000 non-null  float64
#  16  Maximum Open Credit           99998 non-null   float64
#  17  Bankruptcies                  99796 non-null   float64
#  18  Tax Liens                     99990 non-null   float64
# dtypes: float64(12), object(7)
# memory usage: 14.6+ MB

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
df.isna().sum().plot(kind='bar')    # missing values visualization
# Out:
# <Axes: >

# %%
df[df['Loan ID'].isna()]
# Out:
#        Loan ID Customer ID Loan Status  Current Loan Amount Term  \
# 100000     NaN         NaN         NaN                  NaN  NaN
# 100001     NaN         NaN         NaN                  NaN  NaN
# 100002     NaN         NaN         NaN                  NaN  NaN
# 100003     NaN         NaN         NaN                  NaN  NaN
# 100004     NaN         NaN         NaN                  NaN  NaN
# ...        ...         ...         ...                  ...  ...
# 100509     NaN         NaN         NaN                  NaN  NaN
# 100510     NaN         NaN         NaN                  NaN  NaN
# 100511     NaN         NaN         NaN                  NaN  NaN
# 100512     NaN         NaN         NaN                  NaN  NaN
# 100513     NaN         NaN         NaN                  NaN  NaN
#
#         Credit Score  Annual Income Years in current job Home Ownership  \
# 100000           NaN            NaN                  NaN            NaN
# 100001           NaN            NaN                  NaN            NaN
# 100002           NaN            NaN                  NaN            NaN
# 100003           NaN            NaN                  NaN            NaN
# 100004           NaN            NaN                  NaN            NaN
# ...              ...            ...                  ...            ...
# 100509           NaN            NaN                  NaN            NaN
# 100510           NaN            NaN                  NaN            NaN
# 100511           NaN            NaN                  NaN            NaN
# 100512           NaN            NaN                  NaN            NaN
# 100513           NaN            NaN                  NaN            NaN
#
#        Purpose  Monthly Debt  Years of Credit History  \
# 100000     NaN           NaN                      NaN
# 100001     NaN           NaN                      NaN
# 100002     NaN           NaN                      NaN
# 100003     NaN           NaN                      NaN
# 100004     NaN           NaN                      NaN
# ...        ...           ...                      ...
# 100509     NaN           NaN                      NaN
# 100510     NaN           NaN                      NaN
# 100511     NaN           NaN                      NaN
# 100512     NaN           NaN                      NaN
# 100513     NaN           NaN                      NaN
#
#         Months since last delinquent  Number of Open Accounts  \
# 100000                           NaN                      NaN
# 100001                           NaN                      NaN
# 100002                           NaN                      NaN
# 100003                           NaN                      NaN
# 100004                           NaN                      NaN
# ...                              ...                      ...
# 100509                           NaN                      NaN
# 100510                           NaN                      NaN
# 100511                           NaN                      NaN
# 100512                           NaN                      NaN
# 100513                           NaN                      NaN
#
#         Number of Credit Problems  Current Credit Balance  \
# 100000                        NaN                     NaN
# 100001                        NaN                     NaN
# 100002                        NaN                     NaN
# 100003                        NaN                     NaN
# 100004                        NaN                     NaN
# ...                           ...                     ...
# 100509                        NaN                     NaN
# 100510                        NaN                     NaN
# 100511                        NaN                     NaN
# 100512                        NaN                     NaN
# 100513                        NaN                     NaN
#
#         Maximum Open Credit  Bankruptcies  Tax Liens
# 100000                  NaN           NaN        NaN
# 100001                  NaN           NaN        NaN
# 100002                  NaN           NaN        NaN
# 100003                  NaN           NaN        NaN
# 100004                  NaN           NaN        NaN
# ...                     ...           ...        ...
# 100509                  NaN           NaN        NaN
# 100510                  NaN           NaN        NaN
# 100511                  NaN           NaN        NaN
# 100512                  NaN           NaN        NaN
# 100513                  NaN           NaN        NaN
#
# [514 rows x 19 columns]

# %%
# We will delete these rows from our data because all columns are having null values here.

# %%
df= df.dropna(axis = 0, subset = ['Loan ID'])

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Months since last delinquent    53141
# Credit Score                    19154
# Annual Income                   19154
# Years in current job             4222
# Bankruptcies                      204
# Tax Liens                          10
# Maximum Open Credit                 2
# Years of Credit History             0
# Current Credit Balance              0
# Number of Credit Problems           0
# Number of Open Accounts             0
# Loan ID                             0
# Monthly Debt                        0
# Customer ID                         0
# Home Ownership                      0
# Term                                0
# Current Loan Amount                 0
# Loan Status                         0
# Purpose                             0
# dtype: int64

# %%
df[df['Tax Liens'].isna()]
# Out:
#                                     Loan ID  \
# 9632   62eb07d6-2042-4e7e-92e5-c64e5c5e550f
# 10546  bb27f262-7982-4478-9d85-768ecca4fb88
# 19274  8a2eb784-0682-4314-bb93-daa50a7c7c99
# 20727  3a17105b-d1f5-460c-a582-829153486728
# 28595  96e9fc0f-ff00-4526-85ee-a62b904d9db6
# 28811  c4fbf5ff-0b79-44f4-9099-dd9e96e909ec
# 43369  8d5a40cc-230c-45f8-91f1-3c3afa7bb97f
# 46430  8f6af143-49e2-4fff-b729-8a2be6bf71a3
# 57336  bb27f262-7982-4478-9d85-768ecca4fb88
# 86062  96e9fc0f-ff00-4526-85ee-a62b904d9db6
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 9632   3ffba32a-149b-4346-b433-a9fedfb2fb4c  Fully Paid           99999999.0
# 10546  d877718e-a063-42c5-a4df-753bb089e51b  Fully Paid             110792.0
# 19274  991c0c76-0432-4b11-8186-2da07e8f3a71  Fully Paid             118712.0
# 20727  e743f01f-d0da-40a3-a8be-4586988ffe07  Fully Paid              78738.0
# 28595  dd68e09b-4123-4372-9236-a71a32a0a8cf  Fully Paid             259952.0
# 28811  09c0e968-6763-4a62-a659-ea980d997a3a  Fully Paid             109362.0
# 43369  3dc3d4b5-e669-4537-9a07-9bbe017fdd9e  Fully Paid              43032.0
# 46430  e6d56246-9fd6-44df-b490-9bb9dc87b881  Fully Paid             111012.0
# 57336  d877718e-a063-42c5-a4df-753bb089e51b  Fully Paid             110792.0
# 86062  dd68e09b-4123-4372-9236-a71a32a0a8cf  Fully Paid             259952.0
#
#              Term  Credit Score  Annual Income Years in current job  \
# 9632   Short Term         632.0       968202.0               1 year
# 10546  Short Term         720.0      1530944.0             < 1 year
# 19274  Short Term         746.0      1431441.0              7 years
# 20727  Short Term         735.0       262276.0             < 1 year
# 28595  Short Term         702.0      1403207.0              9 years
# 28811  Short Term           NaN            NaN             < 1 year
# 43369  Short Term           NaN            NaN            10+ years
# 46430  Short Term           NaN            NaN              8 years
# 57336  Short Term           NaN            NaN             < 1 year
# 86062  Short Term         702.0      1403207.0              9 years
#
#       Home Ownership               Purpose  Monthly Debt  \
# 9632            Rent    Debt Consolidation      10166.14
# 10546       Own Home    Debt Consolidation       1543.75
# 19274  Home Mortgage    Debt Consolidation      17177.33
# 20727           Rent  Educational Expenses       3584.35
# 28595       Own Home    Debt Consolidation      17540.04
# 28811  Home Mortgage                 other      11711.60
# 43369  Home Mortgage    Debt Consolidation        785.46
# 46430  Home Mortgage     Home Improvements          0.00
# 57336       Own Home    Debt Consolidation       1543.75
# 86062       Own Home    Debt Consolidation      17540.04
#
#        Years of Credit History  Months since last delinquent  \
# 9632                      13.0                           0.0
# 10546                     20.0                           0.0
# 19274                     24.5                           0.0
# 20727                     13.6                           0.0
# 28595                     21.3                          78.0
# 28811                     27.7                           0.0
# 43369                     25.1                           NaN
# 46430                     28.6                           0.0
# 57336                     20.0                           0.0
# 86062                     21.3                          78.0
#
#        Number of Open Accounts  Number of Credit Problems  \
# 9632                      12.0                        0.0
# 10546                     15.0                        1.0
# 19274                     15.0                        0.0
# 20727                     10.0                        0.0
# 28595                      9.0                        0.0
# 28811                     17.0                        0.0
# 43369                     14.0                        0.0
# 46430                      2.0                        0.0
# 57336                     15.0                        1.0
# 86062                      9.0                        0.0
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 9632                  57038.0              71566.0           NaN        NaN
# 10546                520239.0            3741474.0           NaN        NaN
# 19274                132392.0            1064536.0           NaN        NaN
# 20727                 55632.0             156750.0           NaN        NaN
# 28595                805239.0             998250.0           NaN        NaN
# 28811               1617090.0          267490058.0           NaN        NaN
# 43369                 87476.0             547558.0           NaN        NaN
# 46430                116071.0             689194.0           NaN        NaN
# 57336                520239.0            3741474.0           NaN        NaN
# 86062                805239.0             998250.0           NaN        NaN

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
df= df.dropna(axis = 0, subset = ['Tax Liens'])

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Months since last delinquent    53140
# Credit Score                    19150
# Annual Income                   19150
# Years in current job             4222
# Bankruptcies                      194
# Maximum Open Credit                 2
# Loan ID                             0
# Years of Credit History             0
# Current Credit Balance              0
# Number of Credit Problems           0
# Number of Open Accounts             0
# Purpose                             0
# Monthly Debt                        0
# Customer ID                         0
# Home Ownership                      0
# Term                                0
# Current Loan Amount                 0
# Loan Status                         0
# Tax Liens                           0
# dtype: int64

# %%
df = df.dropna(axis = 0, subset = ['Maximum Open Credit'])

# %%
df['Bankruptcies']= df['Bankruptcies'].fillna(0)

# %%
df['Credit Score']= df['Credit Score'].fillna(df['Credit Score'].mean())

# %%
df['Annual Income'] = df['Annual Income'].fillna(df['Annual Income'].mean())

# %%
df['Years in current job'] = df['Years in current job'].fillna(df['Years in current job'].mode()[0])

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Months since last delinquent    53140
# Loan ID                             0
# Monthly Debt                        0
# Bankruptcies                        0
# Maximum Open Credit                 0
# Current Credit Balance              0
# Number of Credit Problems           0
# Number of Open Accounts             0
# Years of Credit History             0
# Purpose                             0
# Customer ID                         0
# Home Ownership                      0
# Years in current job                0
# Annual Income                       0
# Credit Score                        0
# Term                                0
# Current Loan Amount                 0
# Loan Status                         0
# Tax Liens                           0
# dtype: int64

# %%
df= df.drop(['Months since last delinquent'], axis=1)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Loan ID                      0
# Customer ID                  0
# Bankruptcies                 0
# Maximum Open Credit          0
# Current Credit Balance       0
# Number of Credit Problems    0
# Number of Open Accounts      0
# Years of Credit History      0
# Monthly Debt                 0
# Purpose                      0
# Home Ownership               0
# Years in current job         0
# Annual Income                0
# Credit Score                 0
# Term                         0
# Current Loan Amount          0
# Loan Status                  0
# Tax Liens                    0
# dtype: int64

# %%
df['Debt_to_Income'] = (df['Monthly Debt']) / (df['Annual Income']/12)
df['Loan_to_Income'] = (df['Current Loan Amount']) / (df['Annual Income'])

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Loan ID                      0
# Customer ID                  0
# Debt_to_Income               0
# Tax Liens                    0
# Bankruptcies                 0
# Maximum Open Credit          0
# Current Credit Balance       0
# Number of Credit Problems    0
# Number of Open Accounts      0
# Years of Credit History      0
# Monthly Debt                 0
# Purpose                      0
# Home Ownership               0
# Years in current job         0
# Annual Income                0
# Credit Score                 0
# Term                         0
# Current Loan Amount          0
# Loan Status                  0
# Loan_to_Income               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Number of Open Accounts', 'Number of Credit Problems',
#        'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies',
#        'Tax Liens', 'Debt_to_Income', 'Loan_to_Income'],
#       dtype='object')

# %%
X= df.drop(['Loan ID', 'Customer ID','Loan Status',  'Bankruptcies', 'Tax Liens'], axis=1)

# %%
Y=df[['Loan Status']]

# %%
cat=[]
con=[]

for i in X.columns:
    if X[i].dtypes==object:
        cat.append(i)
    else:
        con.append(i)

# %%
print('Cat columns: ', cat)
print('Con columns: ', con)
# Out:
# Cat columns:  ['Term', 'Years in current job', 'Home Ownership', 'Purpose']
# Con columns:  ['Current Loan Amount', 'Credit Score', 'Annual Income', 'Monthly Debt', 'Years of Credit History', 'Number of Open Accounts', 'Number of Credit Problems', 'Current Credit Balance', 'Maximum Open Credit', 'Debt_to_Income', 'Loan_to_Income']

# %%
Y= Y.replace(['Fully Paid','Charged Off'], [0,1])

# %%
Y.value_counts()
# Out:
# Loan Status
# 0              77351
# 1              22637
# Name: count, dtype: int64

# %%
Y.head()
# Out:
#    Loan Status
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
Xcat= X[cat]
Xcon= X[con]

# %%
Xcat.shape
# Out:
# (99988, 4)

# %%
Xcon.shape
# Out:
# (99988, 11)

# %%
X.shape
# Out:
# (99988, 15)

# %%
Xcon
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0                 445412.0    709.000000   1.167493e+06       5214.74
# 1                 262328.0   1076.409926   1.378287e+06      33295.98
# 2               99999999.0    741.000000   2.231892e+06      29200.53
# 3                 347666.0    721.000000   8.069490e+05       8741.90
# 4                 176220.0   1076.409926   1.378287e+06      20639.70
# ...                    ...           ...            ...           ...
# 99995             147070.0    725.000000   4.754370e+05       2202.86
# 99996           99999999.0    732.000000   1.289416e+06      13109.05
# 99997             103136.0    742.000000   1.150545e+06       7315.57
# 99998             530332.0    746.000000   1.717524e+06       9890.07
# 99999           99999999.0    743.000000   9.351800e+05       9118.10
#
#        Years of Credit History  Number of Open Accounts  \
# 0                         17.2                      6.0
# 1                         21.1                     35.0
# 2                         14.9                     18.0
# 3                         12.0                      9.0
# 4                          6.1                     15.0
# ...                        ...                      ...
# 99995                     22.3                      5.0
# 99996                      9.4                     22.0
# 99997                     18.8                     12.0
# 99998                     15.0                      8.0
# 99999                     13.0                      4.0
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                            1.0                228190.0             416746.0
# 1                            0.0                229976.0             850784.0
# 2                            1.0                297996.0             750090.0
# 3                            0.0                256329.0             386958.0
# 4                            0.0                253460.0             427174.0
# ...                          ...                     ...                  ...
# 99995                        0.0                 47766.0             658548.0
# 99996                        0.0                153045.0             509234.0
# 99997                        1.0                109554.0             537548.0
# 99998                        0.0                404225.0             738254.0
# 99999                        1.0                 45600.0              91014.0
#
#        Debt_to_Income  Loan_to_Income
# 0            0.053599        0.381511
# 1            0.289890        0.190329
# 2            0.157000       44.805035
# 3            0.129999        0.430840
# 4            0.179699        0.127854
# ...               ...             ...
# 99995        0.055600        0.309336
# 99996        0.122000       77.554489
# 99997        0.076300        0.089641
# 99998        0.069100        0.308777
# 99999        0.117001      106.931285
#
# [99988 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
Xcon= pd.DataFrame(ss.fit_transform(Xcon),columns= con)
Xcon
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0                -0.356008 -2.769696e-01      -0.216790     -1.089016
# 1                -0.361768 -1.714042e-16       0.000000      1.217479
# 2                 2.776193 -2.528466e-01       0.877885      0.881093
# 3                -0.359083 -2.679235e-01      -0.587589     -0.799308
# 4                -0.364477 -1.714042e-16       0.000000      0.177936
# ...                    ...           ...            ...           ...
# 99983            -0.365394 -2.649081e-01      -0.928531     -1.336401
# 99984             2.776193 -2.596312e-01      -0.091399     -0.440605
# 99985            -0.366777 -2.520928e-01      -0.234220     -0.916461
# 99986            -0.353336 -2.490774e-01       0.348886     -0.705001
# 99987             2.776193 -2.513389e-01      -0.455711     -0.768408
#
#        Years of Credit History  Number of Open Accounts  \
# 0                    -0.142371                -1.023687
# 1                     0.413546                 4.764859
# 2                    -0.470220                 1.371573
# 3                    -0.883594                -0.424872
# 4                    -1.724597                 0.772758
# ...                        ...                      ...
# 99983                 0.584597                -1.223293
# 99984                -1.254206                 2.169993
# 99985                 0.085697                 0.173943
# 99986                -0.455966                -0.624477
# 99987                -0.741051                -1.422898
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                       1.722944               -0.176618            -0.040916
# 1                      -0.348675               -0.171870             0.011113
# 2                       1.722944                0.008960            -0.000958
# 3                      -0.348675               -0.101811            -0.044487
# 4                      -0.348675               -0.109438            -0.039666
# ...                          ...                     ...                  ...
# 99983                  -0.348675               -0.656271            -0.011931
# 99984                  -0.348675               -0.376389            -0.029829
# 99985                   1.722944               -0.492009            -0.026435
# 99986                  -0.348675                0.291368            -0.002376
# 99987                   1.722944               -0.662029            -0.079961
#
#        Debt_to_Income  Loan_to_Income
# 0           -1.363911       -0.302785
# 1            1.407279       -0.308241
# 2           -0.151244        0.964999
# 3           -0.467902       -0.301377
# 4            0.114967       -0.310024
# ...               ...             ...
# 99983       -1.340448       -0.304845
# 99984       -0.561718        1.899622
# 99985       -1.097678       -0.311115
# 99986       -1.182122       -0.304861
# 99987       -0.620342        2.737994
#
# [99988 rows x 11 columns]

# %%
out= []

for i in Xcon.columns:
    ol= Xcon[(Xcon[i]>3)|(Xcon[i]<-3)].index
    out.extend(ol)

# %%
out
# Out:
# [5,
#  43,
#  51,
#  56,
#  65,
#  97,
#  117,
#  160,
#  165,
#  200,
#  216,
#  221,
#  276,
#  303,
#  307,
#  365,
#  383,
#  385,
#  389,
#  406,
#  410,
#  449,
#  509,
#  535,
#  558,
#  602,
#  609,
#  663,
#  673,
#  679,
#  693,
#  695,
#  732,
#  749,
#  776,
#  786,
#  788,
#  792,
#  802,
#  814,
#  824,
#  825,
#  842,
#  892,
#  902,
#  930,
#  996,
#  1051,
#  1094,
#  1127,
#  1146,
#  1165,
#  1180,
#  1187,
#  1189,
#  1298,
#  1373,
#  1375,
#  1410,
#  1422,
#  1428,
#  1496,
#  1507,
#  1515,
#  1525,
#  1538,
#  1548,
#  1554,
#  1619,
#  1621,
#  1637,
#  1643,
#  1656,
#  1658,
#  1666,
#  1682,
#  1692,
#  1708,
#  1723,
#  1728,
#  1744,
#  1754,
#  1807,
#  1870,
#  1874,
#  1886,
#  1900,
#  1905,
#  1916,
#  1930,
#  1935,
#  1944,
#  1950,
#  1965,
#  2004,
#  2046,
#  2064,
#  2065,
#  2070,
#  2095,
#  2103,
#  2150,
#  2161,
#  2177,
#  2183,
#  2192,
#  2197,
#  2236,
#  2241,
#  2270,
#  2277,
#  2292,
#  2303,
#  2341,
#  2363,
#  2428,
#  2434,
#  2478,
#  2486,
#  2517,
#  2523,
#  2555,
#  2559,
#  2573,
#  2600,
#  2624,
#  2646,
#  2659,
#  2664,
#  2674,
#  2679,
#  2688,
#  2697,
#  2711,
#  2732,
#  2751,
#  2757,
#  2773,
#  2792,
#  2835,
#  2847,
#  2849,
#  2885,
#  2903,
#  2920,
#  2931,
#  3008,
#  3022,
#  3061,
#  3066,
#  3103,
#  3125,
#  3151,
#  3200,
#  3205,
#  3213,
#  3223,
#  3230,
#  3233,
#  3283,
#  3287,
#  3303,
#  3306,
#  3315,
#  3354,
#  3400,
#  3430,
#  3442,
#  3454,
#  3508,
#  3524,
#  3533,
#  3567,
#  3637,
#  3681,
#  3706,
#  3748,
#  3775,
#  3788,
#  3813,
#  3848,
#  3867,
#  3882,
#  3905,
#  3911,
#  3932,
#  3935,
#  3955,
#  3968,
#  3970,
#  3991,
#  4002,
#  4011,
#  4036,
#  4081,
#  4105,
#  4110,
#  4169,
#  4207,
#  4224,
#  4271,
#  4299,
#  4310,
#  4319,
#  4325,
#  4342,
#  4377,
#  4381,
#  4404,
#  4409,
#  4414,
#  4416,
#  4445,
#  4482,
#  4495,
#  4513,
#  4519,
#  4523,
#  4545,
#  4554,
#  4557,
#  4586,
#  4601,
#  4628,
#  4634,
#  4710,
#  4725,
#  4731,
#  4743,
#  4744,
#  4760,
#  4779,
#  4781,
#  4788,
#  4801,
#  4835,
#  4870,
#  4888,
#  4897,
#  4920,
#  4945,
#  4952,
#  4965,
#  4986,
#  4998,
#  5053,
#  5079,
#  5119,
#  5131,
#  5135,
#  5157,
#  5159,
#  5168,
#  5178,
#  5216,
#  5232,
#  5266,
#  5267,
#  5279,
#  5287,
#  5305,
#  5343,
#  5364,
#  5375,
#  5379,
#  5387,
#  5394,
#  5395,
#  5440,
#  5473,
#  5481,
#  5550,
#  5557,
#  5594,
#  5607,
#  5631,
#  5672,
#  5721,
#  5730,
#  5731,
#  5732,
#  5785,
#  5801,
#  5830,
#  5853,
#  5854,
#  5873,
#  5881,
#  5889,
#  5909,
#  5973,
#  5991,
#  6023,
#  6029,
#  6062,
#  6064,
#  6069,
#  6075,
#  6077,
#  6086,
#  6115,
#  6123,
#  6130,
#  6133,
#  6137,
#  6147,
#  6150,
#  6182,
#  6240,
#  6266,
#  6274,
#  6283,
#  6286,
#  6295,
#  6307,
#  6347,
#  6382,
#  6426,
#  6449,
#  6459,
#  6461,
#  6468,
#  6473,
#  6513,
#  6516,
#  6517,
#  6554,
#  6572,
#  6591,
#  6600,
#  6629,
#  6654,
#  6660,
#  6662,
#  6669,
#  6670,
#  6686,
#  6731,
#  6763,
#  6777,
#  6820,
#  6830,
#  6835,
#  6848,
#  6881,
#  6892,
#  6932,
#  6960,
#  6997,
#  7017,
#  7067,
#  7071,
#  7080,
#  7082,
#  7095,
#  7118,
#  7145,
#  7160,
#  7188,
#  7200,
#  7241,
#  7296,
#  7299,
#  7317,
#  7339,
#  7395,
#  7401,
#  7403,
#  7436,
#  7449,
#  7461,
#  7466,
#  7511,
#  7515,
#  7530,
#  7545,
#  7562,
#  7623,
#  7648,
#  7675,
#  7733,
#  7742,
#  7763,
#  7781,
#  7794,
#  7800,
#  7817,
#  7828,
#  7870,
#  7904,
#  7937,
#  7947,
#  7953,
#  8010,
#  8011,
#  8013,
#  8023,
#  8027,
#  8034,
#  8065,
#  8086,
#  8115,
#  8127,
#  8128,
#  8153,
#  8176,
#  8194,
#  8199,
#  8213,
#  8231,
#  8237,
#  8269,
#  8365,
#  8372,
#  8391,
#  8405,
#  8436,
#  8566,
#  8581,
#  8632,
#  8636,
#  8651,
#  8663,
#  8685,
#  8691,
#  8726,
#  8741,
#  8763,
#  8772,
#  8797,
#  8837,
#  8865,
#  8869,
#  8899,
#  8908,
#  8909,
#  8943,
#  8986,
#  8988,
#  8990,
#  8994,
#  9018,
#  9026,
#  9042,
#  9073,
#  9080,
#  9107,
#  9121,
#  9148,
#  9153,
#  9162,
#  9173,
#  9180,
#  9203,
#  9205,
#  9248,
#  9290,
#  9304,
#  9318,
#  9356,
#  9394,
#  9406,
#  9456,
#  9491,
#  9581,
#  9590,
#  9597,
#  9599,
#  9603,
#  9606,
#  9638,
#  9641,
#  9668,
#  9671,
#  9684,
#  9718,
#  9768,
#  9788,
#  9818,
#  9819,
#  9825,
#  9826,
#  9827,
#  9880,
#  9893,
#  9906,
#  9907,
#  9935,
#  9943,
#  9971,
#  9973,
#  9987,
#  10004,
#  10070,
#  10073,
#  10077,
#  10094,
#  10105,
#  10139,
#  10144,
#  10155,
#  10156,
#  10172,
#  10178,
#  10184,
#  10200,
#  10211,
#  10224,
#  10257,
#  10287,
#  10291,
#  10345,
#  10352,
#  10354,
#  10363,
#  10389,
#  10396,
#  10442,
#  10452,
#  10464,
#  10473,
#  10491,
#  10498,
#  10519,
#  10603,
#  10613,
#  10635,
#  10647,
#  10719,
#  10723,
#  10724,
#  10734,
#  10769,
#  10779,
#  10780,
#  10791,
#  10793,
#  10870,
#  10888,
#  10891,
#  10899,
#  10907,
#  10923,
#  10935,
#  10951,
#  10964,
#  10978,
#  11057,
#  11125,
#  11135,
#  11162,
#  11176,
#  11222,
#  11242,
#  11283,
#  11289,
#  11295,
#  11310,
#  11319,
#  11333,
#  11353,
#  11363,
#  11377,
#  11421,
#  11430,
#  11512,
#  11516,
#  11527,
#  11548,
#  11560,
#  11574,
#  11577,
#  11581,
#  11665,
#  11669,
#  11673,
#  11674,
#  11702,
#  11742,
#  11825,
#  11845,
#  11850,
#  11851,
#  11856,
#  11862,
#  11884,
#  11930,
#  11954,
#  11972,
#  12007,
#  12009,
#  12053,
#  12100,
#  12139,
#  12155,
#  12185,
#  12202,
#  12205,
#  12218,
#  12223,
#  12226,
#  12238,
#  12251,
#  12253,
#  12274,
#  12343,
#  12383,
#  12426,
#  12432,
#  12462,
#  12467,
#  12496,
#  12509,
#  12512,
#  12514,
#  12542,
#  12605,
#  12622,
#  12631,
#  12645,
#  12653,
#  12691,
#  12693,
#  12710,
#  12731,
#  12758,
#  12772,
#  12775,
#  12778,
#  12860,
#  12871,
#  12899,
#  12932,
#  12982,
#  13070,
#  13079,
#  13081,
#  13100,
#  13127,
#  13161,
#  13186,
#  13195,
#  13202,
#  13256,
#  13272,
#  13291,
#  13304,
#  13313,
#  13314,
#  13317,
#  13327,
#  13340,
#  13377,
#  13401,
#  13415,
#  13428,
#  13432,
#  13526,
#  13553,
#  13585,
#  13586,
#  13652,
#  13658,
#  13682,
#  13684,
#  13688,
#  13697,
#  13699,
#  13700,
#  13718,
#  13719,
#  13720,
#  13757,
#  13863,
#  13866,
#  13886,
#  13899,
#  13924,
#  13970,
#  13979,
#  14055,
#  14071,
#  14129,
#  14165,
#  14200,
#  14211,
#  14213,
#  14245,
#  14278,
#  14291,
#  14331,
#  14373,
#  14433,
#  14434,
#  14437,
#  14477,
#  14588,
#  14607,
#  14622,
#  14633,
#  14634,
#  14643,
#  14661,
#  14689,
#  14700,
#  14745,
#  14776,
#  14829,
#  14843,
#  14877,
#  14884,
#  14885,
#  14891,
#  14920,
#  14927,
#  14984,
#  15008,
#  15047,
#  15052,
#  15149,
#  15160,
#  15165,
#  15169,
#  15170,
#  15203,
#  15209,
#  15258,
#  15325,
#  15344,
#  15408,
#  15431,
#  15432,
#  15452,
#  15462,
#  15514,
#  15574,
#  15628,
#  15640,
#  15643,
#  15657,
#  15670,
#  15687,
#  15692,
#  15695,
#  15700,
#  15724,
#  15788,
#  15794,
#  15808,
#  15809,
#  15829,
#  15835,
#  15849,
#  15855,
#  15863,
#  15873,
#  15929,
#  15945,
#  15950,
#  16000,
#  16016,
#  16018,
#  16029,
#  16052,
#  16060,
#  16090,
#  16102,
#  16137,
#  16152,
#  16156,
#  16166,
#  16169,
#  16191,
#  16194,
#  16205,
#  16209,
#  16211,
#  16214,
#  16282,
#  16291,
#  16298,
#  16302,
#  16323,
#  16348,
#  16355,
#  16379,
#  16406,
#  16434,
#  16462,
#  16487,
#  16491,
#  16526,
#  16568,
#  16585,
#  16598,
#  16633,
#  16653,
#  16716,
#  16719,
#  16737,
#  16866,
#  16871,
#  16927,
#  16944,
#  16947,
#  16969,
#  17013,
#  17017,
#  17031,
#  17032,
#  17043,
#  17052,
#  17085,
#  17086,
#  17107,
#  17111,
#  17113,
#  17127,
#  17130,
#  17174,
#  17189,
#  17207,
#  17213,
#  17225,
#  17236,
#  17253,
#  17311,
#  17316,
#  17328,
#  17331,
#  17334,
#  17367,
#  17391,
#  17453,
#  17456,
#  17478,
#  17487,
#  17500,
#  17520,
#  17535,
#  17545,
#  17610,
#  17633,
#  17649,
#  17653,
#  17663,
#  17686,
#  17690,
#  17715,
#  17743,
#  17746,
#  17780,
#  17825,
#  17843,
#  17869,
#  17880,
#  17925,
#  17930,
#  17931,
#  17934,
#  17984,
#  18006,
#  18040,
#  18073,
#  18126,
#  18182,
#  18208,
#  18240,
#  18252,
#  18289,
#  18293,
#  18336,
#  18343,
#  18369,
#  18375,
#  18422,
#  18437,
#  18442,
#  18479,
#  18488,
#  18528,
#  18539,
#  18549,
#  18573,
#  18577,
#  18578,
#  18579,
#  18593,
#  18605,
#  18611,
#  18644,
#  18648,
#  18682,
#  18737,
#  18800,
#  18806,
#  18850,
#  18864,
#  18867,
#  18880,
#  18893,
#  18914,
#  18959,
#  18966,
#  18982,
#  19011,
#  19029,
#  19067,
#  19088,
#  19091,
#  19094,
#  19110,
#  19111,
#  19126,
#  19141,
#  19149,
#  19152,
#  19155,
#  19158,
#  19198,
#  19205,
#  19305,
#  19333,
#  19346,
#  19406,
#  19422,
#  19443,
#  19462,
#  19471,
#  19484,
#  19543,
#  19544,
#  19563,
#  19566,
#  19568,
#  19587,
#  19598,
#  19632,
#  19647,
#  19724,
#  19768,
#  19779,
#  19784,
#  19805,
#  19809,
#  19820,
#  19829,
#  19910,
#  19917,
#  19923,
#  19957,
#  19974,
#  19981,
#  19993,
#  20105,
#  20119,
#  20178,
#  20201,
#  20207,
#  20236,
#  20264,
#  20308,
#  20321,
#  20369,
#  20385,
#  20416,
#  20457,
#  20513,
#  20526,
#  20540,
#  20626,
#  20648,
#  20659,
#  20664,
#  20667,
#  20681,
#  20682,
#  20691,
#  20701,
#  20721,
#  20732,
#  20751,
#  20775,
#  20782,
#  20811,
#  20846,
#  20848,
#  20852,
#  20865,
#  20868,
#  20878,
#  20880,
#  20896,
#  20991,
#  21028,
#  21029,
#  21064,
#  21073,
#  21090,
#  21121,
#  ...]

# %%
outliers= list(set(out))
outliers
# Out:
# [98304,
#  32769,
#  1,
#  65537,
#  5,
#  65543,
#  98314,
#  10,
#  32780,
#  12,
#  65556,
#  98326,
#  65560,
#  32794,
#  98331,
#  98330,
#  29,
#  32797,
#  65567,
#  98336,
#  32795,
#  32802,
#  98332,
#  36,
#  98341,
#  98344,
#  98345,
#  43,
#  32812,
#  65581,
#  46,
#  65583,
#  32813,
#  51,
#  54,
#  32822,
#  56,
#  65593,
#  98360,
#  32831,
#  65600,
#  65,
#  65602,
#  63,
#  65604,
#  65608,
#  98377,
#  74,
#  76,
#  98382,
#  65615,
#  98385,
#  32851,
#  32853,
#  87,
#  32859,
#  32860,
#  96,
#  97,
#  65634,
#  98403,
#  32864,
#  98405,
#  65638,
#  98402,
#  32872,
#  32875,
#  32881,
#  117,
#  118,
#  65659,
#  98428,
#  32893,
#  65663,
#  98431,
#  130,
#  65667,
#  32899,
#  98440,
#  32905,
#  98441,
#  32910,
#  32912,
#  32913,
#  98451,
#  98454,
#  151,
#  32920,
#  98459,
#  160,
#  161,
#  165,
#  169,
#  32938,
#  98475,
#  32941,
#  98480,
#  179,
#  180,
#  98485,
#  32954,
#  65732,
#  98500,
#  200,
#  65737,
#  65743,
#  98511,
#  32977,
#  65746,
#  216,
#  98522,
#  32987,
#  221,
#  32991,
#  32993,
#  65761,
#  229,
#  32997,
#  65768,
#  98537,
#  233,
#  33002,
#  65771,
#  33011,
#  98547,
#  98548,
#  98551,
#  248,
#  98553,
#  33024,
#  257,
#  65794,
#  65793,
#  98564,
#  98569,
#  33036,
#  268,
#  269,
#  98575,
#  98576,
#  276,
#  65813,
#  33046,
#  98583,
#  65816,
#  98584,
#  285,
#  98590,
#  33057,
#  33059,
#  33063,
#  65833,
#  33067,
#  300,
#  98606,
#  303,
#  98609,
#  306,
#  307,
#  33074,
#  311,
#  312,
#  65850,
#  315,
#  98620,
#  98621,
#  65854,
#  321,
#  98625,
#  98630,
#  33095,
#  98633,
#  329,
#  65867,
#  98638,
#  33107,
#  33113,
#  98651,
#  65891,
#  98659,
#  65895,
#  33129,
#  98666,
#  365,
#  98670,
#  33134,
#  369,
#  65907,
#  65908,
#  33141,
#  33144,
#  376,
#  98682,
#  378,
#  98684,
#  379,
#  33150,
#  383,
#  33145,
#  385,
#  65918,
#  389,
#  65925,
#  33162,
#  396,
#  33166,
#  65934,
#  65937,
#  65938,
#  403,
#  33172,
#  65941,
#  406,
#  33169,
#  410,
#  411,
#  33183,
#  65953,
#  98722,
#  33190,
#  65959,
#  65960,
#  33198,
#  33199,
#  33203,
#  98740,
#  98741,
#  33205,
#  33207,
#  65976,
#  65977,
#  98739,
#  444,
#  33215,
#  449,
#  33218,
#  451,
#  65987,
#  65988,
#  454,
#  459,
#  33228,
#  98764,
#  460,
#  462,
#  98768,
#  66001,
#  65999,
#  33233,
#  98772,
#  473,
#  98780,
#  476,
#  33244,
#  480,
#  98786,
#  66021,
#  33254,
#  33256,
#  98793,
#  98797,
#  66033,
#  33267,
#  504,
#  66041,
#  66042,
#  33275,
#  98811,
#  509,
#  511,
#  513,
#  514,
#  516,
#  98820,
#  33286,
#  66055,
#  98824,
#  33287,
#  98828,
#  529,
#  33302,
#  535,
#  98839,
#  98841,
#  542,
#  33314,
#  550,
#  78264,
#  66088,
#  552,
#  66090,
#  98857,
#  66092,
#  33324,
#  558,
#  33328,
#  98867,
#  66099,
#  66103,
#  98872,
#  98874,
#  66107,
#  33341,
#  98879,
#  98886,
#  98887,
#  66119,
#  98889,
#  98890,
#  98892,
#  589,
#  66129,
#  594,
#  33363,
#  33361,
#  33364,
#  98902,
#  33366,
#  98905,
#  602,
#  98906,
#  66140,
#  98908,
#  66142,
#  603,
#  33370,
#  609,
#  66149,
#  66151,
#  616,
#  66153,
#  619,
#  33390,
#  626,
#  98930,
#  66169,
#  33402,
#  33403,
#  636,
#  98937,
#  98944,
#  643,
#  644,
#  33411,
#  647,
#  66186,
#  33420,
#  653,
#  66190,
#  66191,
#  66192,
#  98961,
#  657,
#  33427,
#  658,
#  662,
#  663,
#  664,
#  66204,
#  670,
#  673,
#  33441,
#  98982,
#  679,
#  33452,
#  66221,
#  98989,
#  66223,
#  33456,
#  691,
#  693,
#  694,
#  695,
#  98999,
#  33461,
#  99002,
#  66237,
#  702,
#  99005,
#  99012,
#  33478,
#  99014,
#  99016,
#  66248,
#  33482,
#  33484,
#  99024,
#  721,
#  66256,
#  33491,
#  66259,
#  66261,
#  33493,
#  66263,
#  99025,
#  33488,
#  66267,
#  732,
#  734,
#  736,
#  66274,
#  33506,
#  66277,
#  744,
#  747,
#  748,
#  749,
#  66285,
#  99051,
#  66288,
#  33520,
#  99058,
#  33521,
#  66289,
#  99064,
#  66299,
#  33531,
#  99069,
#  99070,
#  99072,
#  776,
#  777,
#  778,
#  66315,
#  99084,
#  99080,
#  99087,
#  33551,
#  784,
#  786,
#  66322,
#  788,
#  789,
#  66326,
#  99094,
#  792,
#  66331,
#  99102,
#  66337,
#  802,
#  99107,
#  66342,
#  33576,
#  33579,
#  814,
#  33584,
#  66352,
#  818,
#  66355,
#  99125,
#  824,
#  825,
#  826,
#  66362,
#  99132,
#  33593,
#  66363,
#  842,
#  66378,
#  66380,
#  99146,
#  33614,
#  66383,
#  99152,
#  33617,
#  848,
#  33615,
#  99153,
#  853,
#  33621,
#  99159,
#  856,
#  99162,
#  66397,
#  99166,
#  33634,
#  33640,
#  874,
#  33643,
#  33644,
#  877,
#  33646,
#  99182,
#  876,
#  99185,
#  33650,
#  66418,
#  879,
#  99189,
#  99190,
#  99186,
#  66424,
#  66425,
#  33656,
#  892,
#  66428,
#  99200,
#  33665,
#  99205,
#  902,
#  66440,
#  99210,
#  33675,
#  33677,
#  66446,
#  66447,
#  99216,
#  66451,
#  99222,
#  33688,
#  33689,
#  66460,
#  66461,
#  99229,
#  33694,
#  33693,
#  930,
#  66467,
#  932,
#  33702,
#  66471,
#  33705,
#  33711,
#  99249,
#  33714,
#  948,
#  99253,
#  33720,
#  954,
#  33724,
#  66496,
#  33728,
#  965,
#  967,
#  66504,
#  66506,
#  99274,
#  33740,
#  66508,
#  33749,
#  983,
#  66520,
#  99289,
#  66522,
#  99294,
#  99298,
#  99299,
#  996,
#  99301,
#  994,
#  995,
#  33763,
#  66536,
#  1003,
#  1006,
#  33775,
#  1011,
#  66549,
#  33785,
#  99324,
#  66556,
#  33790,
#  66559,
#  1024,
#  33794,
#  99331,
#  33797,
#  1030,
#  66571,
#  1035,
#  99343,
#  1040,
#  33810,
#  66579,
#  66578,
#  99346,
#  1051,
#  66587,
#  99359,
#  66591,
#  1057,
#  33827,
#  33828,
#  1064,
#  33832,
#  66603,
#  99371,
#  99373,
#  33836,
#  1071,
#  1074,
#  33843,
#  1076,
#  33849,
#  1081,
#  66619,
#  33854,
#  1089,
#  33857,
#  66627,
#  33860,
#  1094,
#  66630,
#  99398,
#  66635,
#  33869,
#  66637,
#  66638,
#  66642,
#  66643,
#  66646,
#  33885,
#  66654,
#  99425,
#  33894,
#  1127,
#  99433,
#  1132,
#  99440,
#  99441,
#  66676,
#  99446,
#  99447,
#  1143,
#  1144,
#  1146,
#  66682,
#  66683,
#  99452,
#  33915,
#  33916,
#  33917,
#  66689,
#  33920,
#  66696,
#  66698,
#  33931,
#  1165,
#  66702,
#  33933,
#  33936,
#  1170,
#  33939,
#  66712,
#  99481,
#  33946,
#  1179,
#  1180,
#  33953,
#  1187,
#  66724,
#  1189,
#  99492,
#  33956,
#  66725,
#  33963,
#  33965,
#  99504,
#  66739,
#  99512,
#  99513,
#  99514,
#  99515,
#  66746,
#  99517,
#  99518,
#  33983,
#  33982,
#  33985,
#  99521,
#  33987,
#  33988,
#  1220,
#  33981,
#  66762,
#  66763,
#  99531,
#  99530,
#  1230,
#  66770,
#  1235,
#  34004,
#  1237,
#  34003,
#  34005,
#  1239,
#  99545,
#  34010,
#  99540,
#  1244,
#  66783,
#  1248,
#  34025,
#  34027,
#  1260,
#  99565,
#  34030,
#  66799,
#  66795,
#  1266,
#  66804,
#  34038,
#  66808,
#  34040,
#  34043,
#  34045,
#  34048,
#  34049,
#  34051,
#  66822,
#  66824,
#  1288,
#  66826,
#  1298,
#  66836,
#  34069,
#  99607,
#  66840,
#  99608,
#  66844,
#  34077,
#  99612,
#  1313,
#  1314,
#  99617,
#  1315,
#  66858,
#  1329,
#  66865,
#  99635,
#  34100,
#  34104,
#  99641,
#  66873,
#  99648,
#  99652,
#  66886,
#  99658,
#  66890,
#  34124,
#  34134,
#  1368,
#  34136,
#  66906,
#  66907,
#  34140,
#  1373,
#  99678,
#  1375,
#  99679,
#  34149,
#  66918,
#  1384,
#  34154,
#  1389,
#  66927,
#  66931,
#  99700,
#  1397,
#  99699,
#  1402,
#  66939,
#  34170,
#  99709,
#  99711,
#  1410,
#  66947,
#  99716,
#  66949,
#  99718,
#  66951,
#  99721,
#  99723,
#  66956,
#  1422,
#  66958,
#  99728,
#  34190,
#  99730,
#  1428,
#  66971,
#  34206,
#  1442,
#  34210,
#  1444,
#  34214,
#  1446,
#  66986,
#  99756,
#  34222,
#  66991,
#  66992,
#  99765,
#  66998,
#  66999,
#  34232,
#  99769,
#  1464,
#  99772,
#  1469,
#  34245,
#  67014,
#  1479,
#  34249,
#  34251,
#  34252,
#  1485,
#  34254,
#  67023,
#  67024,
#  1483,
#  67029,
#  67030,
#  1496,
#  67033,
#  99806,
#  1507,
#  67044,
#  34277,
#  67045,
#  1510,
#  67048,
#  99812,
#  1515,
#  34288,
#  67056,
#  1520,
#  67059,
#  1525,
#  99831,
#  34296,
#  34298,
#  34300,
#  99839,
#  34304,
#  1538,
#  34307,
#  99842,
#  99846,
#  67079,
#  34312,
#  1546,
#  1547,
#  1548,
#  1554,
#  99860,
#  67098,
#  34330,
#  1565,
#  34334,
#  34337,
#  34339,
#  1574,
#  99882,
#  99883,
#  1578,
#  99885,
#  99890,
#  67122,
#  99892,
#  99894,
#  67128,
#  67129,
#  34361,
#  67137,
#  99908,
#  67142,
#  99911,
#  34376,
#  1606,
#  67144,
#  67148,
#  1613,
#  1614,
#  67151,
#  1612,
#  67153,
#  67150,
#  1619,
#  1621,
#  67157,
#  67159,
#  67160,
#  1624,
#  67162,
#  1627,
#  99932,
#  99935,
#  67168,
#  67167,
#  67170,
#  34403,
#  1636,
#  1637,
#  99942,
#  34408,
#  1643,
#  99952,
#  67185,
#  67184,
#  99955,
#  67189,
#  1656,
#  1658,
#  1666,
#  34438,
#  34444,
#  67213,
#  34447,
#  34448,
#  1682,
#  34452,
#  34454,
#  67223,
#  1686,
#  1692,
#  67229,
#  67236,
#  34469,
#  1703,
#  34473,
#  67242,
#  1708,
#  67250,
#  67251,
#  67252,
#  1721,
#  1723,
#  34495,
#  1728,
#  1731,
#  34500,
#  67268,
#  34504,
#  34505,
#  34508,
#  1740,
#  1744,
#  1751,
#  67289,
#  1754,
#  67291,
#  67293,
#  1760,
#  34528,
#  1767,
#  34547,
#  34550,
#  1783,
#  34554,
#  34558,
#  34561,
#  34567,
#  34568,
#  34569,
#  1800,
#  67336,
#  67340,
#  34574,
#  1807,
#  34578,
#  67353,
#  34589,
#  1823,
#  67378,
#  67392,
#  67393,
#  34626,
#  34624,
#  34627,
#  34629,
#  34633,
#  34635,
#  67404,
#  1870,
#  67408,
#  67409,
#  1874,
#  67411,
#  67415,
#  67419,
#  34652,
#  34653,
#  1886,
#  34656,
#  34657,
#  67429,
#  67433,
#  1899,
#  1900,
#  67437,
#  67439,
#  1904,
#  1905,
#  67442,
#  34677,
#  34679,
#  34682,
#  67451,
#  1916,
#  ...]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (99988, 15)
# (99988, 1)

# %%
X.index= range(0,99988)
Y.index= range(0,99988)

# %%
X= X.drop(index= outliers,axis=0)
Y= Y.drop(index= outliers,axis=0)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (86213, 15)
# (86213, 1)

# %%
X.index= range(0,86213)
Y.index= range(0,86213)

# %% [markdown]
# # Preprocessing

# %%
Xcat= X[cat]
Xcon= X[con]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in Xcat.columns:
    Xcat[i]=le.fit_transform(Xcat[i])
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])

# %%
Xcat
# Out:
#        Term  Years in current job  Home Ownership  Purpose
# 0         1                     8               1        5
# 1         1                     8               2        3
# 2         0                     3               2        3
# 3         1                     5               3        3
# 4         1                    10               1        3
# ...     ...                   ...             ...      ...
# 86208     1                     7               2       11
# 86209     1                     0               3        3
# 86210     1                     6               3        3
# 86211     1                     9               3        3
# 86212     1                     1               2        3
#
# [86213 rows x 4 columns]

# %%
Xcon=pd.DataFrame(ss.fit_transform(Xcon),columns=con)

# %%
Xcon
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0                -0.313136     -0.554523      -0.288990     -1.228108
# 1                 3.144499     -0.338252       1.594739      1.141610
# 2                -0.316531     -0.473421      -0.927066     -0.879636
# 3                -0.322485      1.928603       0.084064      0.295828
# 4                -0.321046     -0.412595      -0.259433     -0.670861
# ...                    ...           ...            ...           ...
# 86208            -0.323498     -0.446387      -1.513762     -1.525672
# 86209             3.144499     -0.399078      -0.073216     -0.448176
# 86210            -0.325023     -0.331493      -0.318984     -1.020553
# 86211            -0.310187     -0.304459       0.684432     -0.766201
# 86212             3.144499     -0.324735      -0.700128     -0.842469
#
#        Years of Credit History  Number of Open Accounts  \
# 0                    -0.092166                -1.068806
# 1                    -0.451755                 1.564510
# 2                    -0.905149                -0.410477
# 3                    -1.827572                 0.906181
# 4                     0.283057                 0.467295
# ...                        ...                      ...
# 86208                 0.705182                -1.288249
# 86209                -1.311640                 2.442282
# 86210                 0.157982                 0.247852
# 86211                -0.436120                -0.629920
# 86212                -0.748806                -1.507692
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                       2.645699               -0.171038            -0.290367
# 1                       2.645699                0.154226             0.247226
# 2                      -0.377972               -0.039923            -0.338406
# 3                      -0.377972               -0.053292            -0.273549
# 4                       2.645699               -0.665044            -0.523718
# ...                          ...                     ...                  ...
# 86208                  -0.377972               -1.011733             0.099594
# 86209                  -0.377972               -0.521180            -0.141209
# 86210                   2.645699               -0.723829            -0.095546
# 86211                  -0.377972                0.649205             0.228137
# 86212                   2.645699               -1.021825            -0.815683
#
#        Debt_to_Income  Loan_to_Income
# 0           -1.395327       -0.296555
# 1           -0.116018        1.720508
# 2           -0.450077       -0.294315
# 3            0.164824       -0.308072
# 4           -0.697520       -0.305532
# ...               ...             ...
# 86208       -1.370574       -0.299832
# 86209       -0.549049        3.207506
# 86210       -1.114463       -0.309807
# 86211       -1.203548       -0.299857
# 86212       -0.610895        4.541368
#
# [86213 rows x 11 columns]

# %%
from scipy.stats import chi2_contingency

# %%
# Feature selection for categorical columns
# Chi-square test

for i in Xcat.columns:
    if i != 'Loan Status':
        # Chi-square test for independence
        contingency_table = pd.crosstab(Xcat[i], df['Loan Status'])
        chi2_stat, p_val, _, _ = chi2_contingency(contingency_table)
        print("Chi-square statistic for", i, ":", chi2_stat)
        print("p-value for", i, ":", p_val)
# Out:
# Chi-square statistic for Term : 0.03744126616492747
# p-value for Term : 0.8465693968379595
# Chi-square statistic for Years in current job : 5.472738839129647
# p-value for Years in current job : 0.8574485152538873
# Chi-square statistic for Home Ownership : 0.8293486963020644
# p-value for Home Ownership : 0.8424350947521926
# Chi-square statistic for Purpose : 17.165762948782486
# p-value for Purpose : 0.3090520683674315

# %%
Xcat.columns
# Out:
# Index(['Term', 'Years in current job', 'Home Ownership', 'Purpose'], dtype='object')

# %%
Xcat= Xcat.drop(['Term', 'Years in current job', 'Home Ownership'], axis=1)

# %%
Xcat.columns
# Out:
# Index(['Purpose'], dtype='object')

# %%
X= Xcon.join(Xcat)

# %%
X.shape
# Out:
# (86213, 12)

# %%
Y.shape
# Out:
# (86213, 1)

# %% [markdown]
# # splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=84)

# %% [markdown]
# # Selected Features

# %%
X.columns
# Out:
# Index(['Current Loan Amount', 'Credit Score', 'Annual Income', 'Monthly Debt',
#        'Years of Credit History', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Debt_to_Income', 'Loan_to_Income', 'Purpose'],
#       dtype='object')

# %% [markdown]
# # Balancing of data

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)

# %%
X_smote, Y_smote = smote.fit_resample(X, Y)

# %%
Y_smote.value_counts()
# Out:
# Loan Status
# 0              69321
# 1              69321
# Name: count, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X_smote,Y_smote,test_size=0.2,random_state=84)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
model= lr.fit(xtrain, ytrain)

tr_pred= model.predict(xtrain)
ts_pred= model.predict(xtest)
# Out:
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score, precision_score,ConfusionMatrixDisplay

# %%
conf_matrix = confusion_matrix(ytest, ts_pred)
conf_display = ConfusionMatrixDisplay(conf_matrix, display_labels=model.classes_)
conf_display.plot()
print(conf_matrix)
# Out:
# [[ 6426  7437]
#  [ 3645 10221]]

# %%
tr_score=accuracy_score(ytrain,tr_pred)
ts_score=accuracy_score(ytest,ts_pred)
print('tr_score= ', tr_score)
print('ts_score= ', ts_score)

tr_recall_score=recall_score(ytrain,tr_pred)
ts_recall_score=recall_score(ytest,ts_pred)
print('tr_recall_score= ', tr_recall_score)
print('ts_recall_score= ', ts_recall_score)

tr_f1_score=f1_score(ytrain,tr_pred)
ts_f1_score=f1_score(ytest,ts_pred)
print('tr_f1_score= ', tr_f1_score)
print('ts_f1_score= ', ts_f1_score)

tr_precision_score=precision_score(ytrain,tr_pred)
ts_precision_score=precision_score(ytest,ts_pred)
print('tr_precision_score= ', tr_precision_score)
print('ts_precision_score= ', ts_precision_score)
# Out:
# tr_score=  0.5997403370209082
# ts_score=  0.6003462079411447
# tr_recall_score=  0.7365792083671445
# ts_recall_score=  0.7371267849415837
# tr_f1_score=  0.647912568999429
# ts_f1_score=  0.648458317472402
# tr_precision_score=  0.5782990953237156
# ts_precision_score=  0.5788311247026844

# %%
# Logistic Regression is bad model here

# %% [markdown]
# # Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier(random_state=42)

model= dtc.fit(xtrain,ytrain)

tr_pred= model.predict(xtrain)
ts_pred= model.predict(xtest)

# %%
conf_matrix = confusion_matrix(ytest, ts_pred)
conf_display = ConfusionMatrixDisplay(conf_matrix, display_labels=model.classes_)
conf_display.plot()
print(conf_matrix)
# Out:
# [[11067  2796]
#  [ 2910 10956]]

# %%
tr_score=accuracy_score(ytrain,tr_pred)
ts_score=accuracy_score(ytest,ts_pred)
print('tr_score= ', tr_score)
print('ts_score= ', ts_score)

tr_recall_score=recall_score(ytrain,tr_pred)
ts_recall_score=recall_score(ytest,ts_pred)
print('tr_recall_score= ', tr_recall_score)
print('ts_recall_score= ', ts_recall_score)

tr_f1_score=f1_score(ytrain,tr_pred)
ts_f1_score=f1_score(ytest,ts_pred)
print('tr_f1_score= ', tr_f1_score)
print('ts_f1_score= ', ts_f1_score)

tr_precision_score=precision_score(ytrain,tr_pred)
ts_precision_score=precision_score(ytest,ts_pred)
print('tr_precision_score= ', tr_precision_score)
print('ts_precision_score= ', ts_precision_score)
# Out:
# tr_score=  1.0
# ts_score=  0.7942226549821486
# tr_recall_score=  1.0
# ts_recall_score=  0.7901341410644742
# tr_f1_score=  1.0
# ts_f1_score=  0.7933956115576798
# tr_precision_score=  1.0
# ts_precision_score=  0.7966841186736475

# %%
# Overfitting is happening here.Model is performing good on training data as compared to testing data

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
                            
model.fit(xtrain,ytrain)
# Out:
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
tr_pred= model.predict(xtrain)
ts_pred= model.predict(xtest)

# %%
# Checking scores

# %%
conf_matrix = confusion_matrix(ytest, ts_pred)
conf_display = ConfusionMatrixDisplay(conf_matrix, display_labels=model.classes_)
conf_display.plot()
print(conf_matrix)
# Out:
# [[11274  2589]
#  [ 1697 12169]]

# %%
tr_score=accuracy_score(ytrain,tr_pred)
ts_score=accuracy_score(ytest,ts_pred)
print('tr_score= ', tr_score)
print('ts_score= ', ts_score)

tr_recall_score=recall_score(ytrain,tr_pred)
ts_recall_score=recall_score(ytest,ts_pred)
print('tr_recall_score= ', tr_recall_score)
print('ts_recall_score= ', ts_recall_score)

tr_f1_score=f1_score(ytrain,tr_pred)
ts_f1_score=f1_score(ytest,ts_pred)
print('tr_f1_score= ', tr_f1_score)
print('ts_f1_score= ', ts_f1_score)

tr_precision_score=precision_score(ytrain,tr_pred)
ts_precision_score=precision_score(ytest,ts_pred)
print('tr_precision_score= ', tr_precision_score)
print('ts_precision_score= ', ts_precision_score)
# Out:
# tr_score=  1.0
# ts_score=  0.8454325796097948
# tr_recall_score=  1.0
# ts_recall_score=  0.8776143083802106
# tr_f1_score=  1.0
# ts_f1_score=  0.8502655114589156
# tr_precision_score=  1.0
# ts_precision_score=  0.8245697248949723

# %%
# Good Model

# %% [markdown]
# # Random forest with adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

rfc= RandomForestClassifier()

model= AdaBoostClassifier(rfc, n_estimators=50)

# %%
model.fit(xtrain,ytrain)

tr_pred= model.predict(xtrain)
ts_pred= model.predict(xtest)
# Out:
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
conf_matrix = confusion_matrix(ytest, ts_pred)
conf_display = ConfusionMatrixDisplay(conf_matrix, display_labels=model.classes_)
conf_display.plot()
print(conf_matrix)
# Out:
# [[11299  2564]
#  [ 1722 12144]]

# %%
tr_score=accuracy_score(ytrain,tr_pred)
ts_score=accuracy_score(ytest,ts_pred)
print('tr_score= ', tr_score)
print('ts_score= ', ts_score)

tr_recall_score=recall_score(ytrain,tr_pred)
ts_recall_score=recall_score(ytest,ts_pred)
print('tr_recall_score= ', tr_recall_score)
print('ts_recall_score= ', ts_recall_score)

tr_f1_score=f1_score(ytrain,tr_pred)
ts_f1_score=f1_score(ytest,ts_pred)
print('tr_f1_score= ', tr_f1_score)
print('ts_f1_score= ', ts_f1_score)

tr_precision_score=precision_score(ytrain,tr_pred)
ts_precision_score=precision_score(ytest,ts_pred)
print('tr_precision_score= ', tr_precision_score)
print('ts_precision_score= ', ts_precision_score)
# Out:
# tr_score=  1.0
# ts_score=  0.8454325796097948
# tr_recall_score=  1.0
# ts_recall_score=  0.8758113370835137
# tr_f1_score=  1.0
# ts_f1_score=  0.8500034996850283
# tr_precision_score=  1.0
# ts_precision_score=  0.8256731030731574

# %%
# Good Model.
# In all models Random Forest Classifier is my best model
# Here Precision and recall both are useful.
# Precision: Ratio of true positives to all predicted positives (avoiding false positives)
# Recall: Ratio of true positives to all actual positives (avoiding false negatives)
# There is always trade-off between Precision and Recall, so it will depend upon organization what is good for them.
# If someone is able to fully pay the loan and they are classified in not able to pay('default'),then its cost will be generally
# high for the company.For that we have to minimize false negatives.We have to improve our Recall score.

# High cost of missed defaults	Recall	Minimize false negatives (loans to risky borrowers).

# High cost of rejected good applicants	Precision	Minimize false positives (rejections of good borrowers)

# %% [markdown]
# # Testing Data

# %%
df2=pd.read_csv('C:/Users/Ashish/Downloads/credit/credit_test.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10353 entries, 0 to 10352
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       10000 non-null  object
#  1   Customer ID                   10000 non-null  object
#  2   Current Loan Amount           10000 non-null  float64
#  3   Term                          10000 non-null  object
#  4   Credit Score                  8019 non-null   float64
#  5   Annual Income                 8019 non-null   float64
#  6   Years in current job          9573 non-null   object
#  7   Home Ownership                10000 non-null  object
#  8   Purpose                       10000 non-null  object
#  9   Monthly Debt                  10000 non-null  float64
#  10  Years of Credit History       10000 non-null  float64
#  11  Months since last delinquent  4694 non-null   float64
#  12  Number of Open Accounts       10000 non-null  float64
#  13  Number of Credit Problems     10000 non-null  float64
#  14  Current Credit Balance        10000 non-null  float64
#  15  Maximum Open Credit           10000 non-null  float64
#  16  Bankruptcies                  9978 non-null   float64
#  17  Tax Liens                     9999 non-null   float64
# dtypes: float64(12), object(6)
# memory usage: 1.4+ MB

# %%
df2.isna().sum()
# Out:
# Loan ID                          353
# Customer ID                      353
# Current Loan Amount              353
# Term                             353
# Credit Score                    2334
# Annual Income                   2334
# Years in current job             780
# Home Ownership                   353
# Purpose                          353
# Monthly Debt                     353
# Years of Credit History          353
# Months since last delinquent    5659
# Number of Open Accounts          353
# Number of Credit Problems        353
# Current Credit Balance           353
# Maximum Open Credit              353
# Bankruptcies                     375
# Tax Liens                        354
# dtype: int64

# %%
df2[df2['Loan ID'].isna()]
# Out:
#       Loan ID Customer ID  Current Loan Amount Term  Credit Score  \
# 10000     NaN         NaN                  NaN  NaN           NaN
# 10001     NaN         NaN                  NaN  NaN           NaN
# 10002     NaN         NaN                  NaN  NaN           NaN
# 10003     NaN         NaN                  NaN  NaN           NaN
# 10004     NaN         NaN                  NaN  NaN           NaN
# ...       ...         ...                  ...  ...           ...
# 10348     NaN         NaN                  NaN  NaN           NaN
# 10349     NaN         NaN                  NaN  NaN           NaN
# 10350     NaN         NaN                  NaN  NaN           NaN
# 10351     NaN         NaN                  NaN  NaN           NaN
# 10352     NaN         NaN                  NaN  NaN           NaN
#
#        Annual Income Years in current job Home Ownership Purpose  \
# 10000            NaN                  NaN            NaN     NaN
# 10001            NaN                  NaN            NaN     NaN
# 10002            NaN                  NaN            NaN     NaN
# 10003            NaN                  NaN            NaN     NaN
# 10004            NaN                  NaN            NaN     NaN
# ...              ...                  ...            ...     ...
# 10348            NaN                  NaN            NaN     NaN
# 10349            NaN                  NaN            NaN     NaN
# 10350            NaN                  NaN            NaN     NaN
# 10351            NaN                  NaN            NaN     NaN
# 10352            NaN                  NaN            NaN     NaN
#
#        Monthly Debt  Years of Credit History  Months since last delinquent  \
# 10000           NaN                      NaN                           NaN
# 10001           NaN                      NaN                           NaN
# 10002           NaN                      NaN                           NaN
# 10003           NaN                      NaN                           NaN
# 10004           NaN                      NaN                           NaN
# ...             ...                      ...                           ...
# 10348           NaN                      NaN                           NaN
# 10349           NaN                      NaN                           NaN
# 10350           NaN                      NaN                           NaN
# 10351           NaN                      NaN                           NaN
# 10352           NaN                      NaN                           NaN
#
#        Number of Open Accounts  Number of Credit Problems  \
# 10000                      NaN                        NaN
# 10001                      NaN                        NaN
# 10002                      NaN                        NaN
# 10003                      NaN                        NaN
# 10004                      NaN                        NaN
# ...                        ...                        ...
# 10348                      NaN                        NaN
# 10349                      NaN                        NaN
# 10350                      NaN                        NaN
# 10351                      NaN                        NaN
# 10352                      NaN                        NaN
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 10000                     NaN                  NaN           NaN        NaN
# 10001                     NaN                  NaN           NaN        NaN
# 10002                     NaN                  NaN           NaN        NaN
# 10003                     NaN                  NaN           NaN        NaN
# 10004                     NaN                  NaN           NaN        NaN
# ...                       ...                  ...           ...        ...
# 10348                     NaN                  NaN           NaN        NaN
# 10349                     NaN                  NaN           NaN        NaN
# 10350                     NaN                  NaN           NaN        NaN
# 10351                     NaN                  NaN           NaN        NaN
# 10352                     NaN                  NaN           NaN        NaN
#
# [353 rows x 18 columns]

# %%
# We will delete these rows from our data because all columns are having null values here.

# %%
df2 = df2.dropna(axis = 0, subset = ['Loan ID'])

# %%
df2.isna().sum().sort_values(ascending=False)
# Out:
# Months since last delinquent    5306
# Credit Score                    1981
# Annual Income                   1981
# Years in current job             427
# Bankruptcies                      22
# Tax Liens                          1
# Maximum Open Credit                0
# Current Credit Balance             0
# Number of Credit Problems          0
# Number of Open Accounts            0
# Loan ID                            0
# Years of Credit History            0
# Customer ID                        0
# Purpose                            0
# Home Ownership                     0
# Term                               0
# Current Loan Amount                0
# Monthly Debt                       0
# dtype: int64

# %%
df2 = df2.dropna(axis = 0, subset = ['Bankruptcies', 'Tax Liens'])

# %%
df2.isna().sum().sort_values(ascending=False)
# Out:
# Months since last delinquent    5306
# Credit Score                    1978
# Annual Income                   1978
# Years in current job             427
# Loan ID                            0
# Bankruptcies                       0
# Maximum Open Credit                0
# Current Credit Balance             0
# Number of Credit Problems          0
# Number of Open Accounts            0
# Monthly Debt                       0
# Years of Credit History            0
# Customer ID                        0
# Purpose                            0
# Home Ownership                     0
# Term                               0
# Current Loan Amount                0
# Tax Liens                          0
# dtype: int64

# %%
df2['Credit Score']= df2['Credit Score'].fillna(df2['Credit Score'].mean())

# %%
df2['Annual Income']= df2['Annual Income'].fillna(df2['Annual Income'].mean())

# %%
df2['Years in current job'] = df2['Years in current job'].fillna(df2['Years in current job'].mode()[0])

# %%
df2= df2.drop(['Months since last delinquent'], axis=1)

# %%
df2.isna().sum().sort_values(ascending=False)
# Out:
# Loan ID                      0
# Monthly Debt                 0
# Bankruptcies                 0
# Maximum Open Credit          0
# Current Credit Balance       0
# Number of Credit Problems    0
# Number of Open Accounts      0
# Years of Credit History      0
# Purpose                      0
# Customer ID                  0
# Home Ownership               0
# Years in current job         0
# Annual Income                0
# Credit Score                 0
# Term                         0
# Current Loan Amount          0
# Tax Liens                    0
# dtype: int64

# %%
df2['Debt_to_Income'] = (df2['Monthly Debt']) / (df2['Annual Income']/12)
df2['Loan_to_Income'] = (df2['Current Loan Amount']) / (df2['Annual Income'])

# %%
df2.isna().sum().sort_values(ascending=False)
# Out:
# Loan ID                      0
# Years of Credit History      0
# Debt_to_Income               0
# Tax Liens                    0
# Bankruptcies                 0
# Maximum Open Credit          0
# Current Credit Balance       0
# Number of Credit Problems    0
# Number of Open Accounts      0
# Monthly Debt                 0
# Customer ID                  0
# Purpose                      0
# Home Ownership               0
# Years in current job         0
# Annual Income                0
# Credit Score                 0
# Term                         0
# Current Loan Amount          0
# Loan_to_Income               0
# dtype: int64

# %%
df2.shape
# Out:
# (9978, 19)

# %% [markdown]
# # Preprocessing

# %%
cat=[]
con=[]
for i in df2.columns:
    if df2[i].dtypes==object:
        cat.append(i)
    else:
        con.append(i)

# %%
Xcat=df2[cat]
Xcon=df2[con]

# %%
Xcon= pd.DataFrame(ss.fit_transform(Xcon),columns=con)

# %%
for i in Xcat.columns:
    Xcat[i]=le.fit_transform(Xcat[i])
# Out:
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\Ashish\AppData\Local\Temp\ipykernel_8608\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])

# %%
Xn=Xcon.join(Xcat)

# %%
Xn
# Out:
#       Current Loan Amount  Credit Score  Annual Income  Monthly Debt  \
# 0               -0.347614 -2.505727e-01   9.048175e-01      1.899448
# 1               -0.358527 -2.603889e-01   7.057484e-01      1.465786
# 2               -0.362111 -2.792662e-01  -6.409590e-01     -0.811456
# 3               -0.361391 -2.656745e-01  -7.579249e-01     -0.135516
# 4               -0.356775 -2.528379e-01   5.026754e-01      1.696019
# ...                   ...           ...            ...           ...
# 9973            -0.361974 -2.626542e-01   1.855905e-01     -1.101535
# 9974            -0.362774 -2.724704e-01  -7.796286e-01     -0.487999
# 9975            -0.359903  1.716886e-16   2.991712e-16     -1.137105
# 9976             2.799585 -2.702051e-01  -5.112003e-01     -0.501685
# 9977             2.799585 -2.498176e-01  -3.726038e-01     -0.501087
#
#       Years of Credit History  Number of Open Accounts  \
# 0                    0.508194                -0.415943
# 1                    0.166261                -0.017223
# 2                   -0.816799                -0.216583
# 3                   -0.246909                 0.979579
# 4                    1.106578                 0.580858
# ...                       ...                      ...
# 9973                -0.816799                -0.415943
# 9974                -1.187227                -0.615304
# 9975                 1.277545                -0.615304
# 9976                -0.204168                -0.615304
# 9977                 0.209002                 0.580858
#
#       Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                     -0.330803                0.851868             0.199616
# 1                     -0.330803                1.000307             0.116661
# 2                     -0.330803               -0.649840            -0.160560
# 3                      1.663610               -0.345038            -0.083640
# 4                     -0.330803                0.177068            -0.117594
# ...                         ...                     ...                  ...
# 9973                  -0.330803               -0.524926            -0.243030
# 9974                  -0.330803               -0.557744            -0.191880
# 9975                   1.663610               -0.492548            -0.063751
# 9976                   1.663610               -0.272848            -0.239676
# 9977                  -0.330803               -0.288206            -0.042540
#
#       Bankruptcies  Tax Liens  Debt_to_Income  Loan_to_Income  Loan ID  \
# 0        -0.332499  -0.106994        0.814924       -0.307705   9659.0
# 1        -0.332499  -0.106994        0.657602       -0.312235   4315.0
# 2        -0.332499  -0.106994       -0.616620       -0.311152   9668.0
# 3         2.525105  -0.106994        0.983490       -0.309706   5125.0
# 4        -0.332499  -0.106994        1.107055       -0.310959    333.0
# ...            ...        ...             ...             ...      ...
# 9973     -0.332499  -0.106994       -1.488596       -0.313245   3475.0
# 9974     -0.332499  -0.106994        0.275567       -0.311225   3244.0
# 9975      2.525105  -0.106994       -1.486984       -0.311537   2856.0
# 9976     -0.332499  -0.106994       -0.218848        2.674758   2575.0
# 9977     -0.332499  -0.106994       -0.387387        2.376023   7195.0
#
#       Customer ID  Term  Years in current job  Home Ownership  Purpose
# 0          8695.0   1.0                   1.0             1.0      3.0
# 1           884.0   1.0                   1.0             1.0      3.0
# 2          1722.0   1.0                   2.0             3.0      3.0
# 3           735.0   1.0                   1.0             3.0      3.0
# 4          2217.0   1.0                   1.0             1.0      3.0
# ...           ...   ...                   ...             ...      ...
# 9973       3059.0   0.0                   5.0             1.0      5.0
# 9974        849.0   1.0                   1.0             3.0      3.0
# 9975       7690.0   0.0                   6.0             3.0      2.0
# 9976       5694.0   1.0                   5.0             3.0     11.0
# 9977       7585.0   0.0                   1.0             1.0      3.0
#
# [9978 rows x 19 columns]

# %%
Xn.isna().sum()
# Out:
# Current Loan Amount           0
# Credit Score                  0
# Annual Income                 0
# Monthly Debt                  0
# Years of Credit History       0
# Number of Open Accounts       0
# Number of Credit Problems     0
# Current Credit Balance        0
# Maximum Open Credit           0
# Bankruptcies                  0
# Tax Liens                     0
# Debt_to_Income                0
# Loan_to_Income                0
# Loan ID                      22
# Customer ID                  22
# Term                         22
# Years in current job         22
# Home Ownership               22
# Purpose                      22
# dtype: int64

# %%
Xn = Xn.dropna(axis = 0, subset = ['Loan ID'])

# %%
Xn.isna().sum()
# Out:
# Current Loan Amount          0
# Credit Score                 0
# Annual Income                0
# Monthly Debt                 0
# Years of Credit History      0
# Number of Open Accounts      0
# Number of Credit Problems    0
# Current Credit Balance       0
# Maximum Open Credit          0
# Bankruptcies                 0
# Tax Liens                    0
# Debt_to_Income               0
# Loan_to_Income               0
# Loan ID                      0
# Customer ID                  0
# Term                         0
# Years in current job         0
# Home Ownership               0
# Purpose                      0
# dtype: int64

# %%
Z=X.columns
q=Xn.columns

# %%
s=[]
for i in q:
    if i not in Z:
        s.append(i)

# %%
s
# Out:
# ['Bankruptcies',
#  'Tax Liens',
#  'Loan ID',
#  'Customer ID',
#  'Term',
#  'Years in current job',
#  'Home Ownership']

# %%
Xm= Xn.drop(labels=s,axis=1)

# %%
new_preds=model.predict(Xm)

# %%
Xm['Loan Status']= new_preds

# %%
Xm['Loan Status']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9973    0
# 9974    0
# 9975    0
# 9976    0
# 9977    0
# Name: Loan Status, Length: 9956, dtype: int64

# %%
Xm['Loan Status'].value_counts()
# Out:
# Loan Status
# 0    9407
# 1     549
# Name: count, dtype: int64

# %%
Xm['Loan Status'].replace([0,1],['Fully Paid','Charged Off'])
# Out:
# 0       Fully Paid
# 1       Fully Paid
# 2       Fully Paid
# 3       Fully Paid
# 4       Fully Paid
#            ...
# 9973    Fully Paid
# 9974    Fully Paid
# 9975    Fully Paid
# 9976    Fully Paid
# 9977    Fully Paid
# Name: Loan Status, Length: 9956, dtype: object

# %%
Xm['Loan Status'].replace([0,1],['Fully Paid','Charged Off'])
# Out:
# 0       Fully Paid
# 1       Fully Paid
# 2       Fully Paid
# 3       Fully Paid
# 4       Fully Paid
#            ...
# 9973    Fully Paid
# 9974    Fully Paid
# 9975    Fully Paid
# 9976    Fully Paid
# 9977    Fully Paid
# Name: Loan Status, Length: 9956, dtype: object

# %%
Xm['Loan Status'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
